# %% [markdown]
# <a href="https://colab.research.google.com/github/vandxor/Python-IITMBS/blob/main/MyFirst_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('hello')
# Out:
# hello

# %% [markdown]
# hello

# %%
print('*')
# Out:
# *
